# %% [markdown]
# <a href="https://colab.research.google.com/github/yash161007jain-gif/AI-SOCIAL-MEDIA-CONTENT-GENERATOR-/blob/main/Copy_of_Your_first_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install all necessary libraries

# %%
# !pip install -q openai google-generativeai # -q means silent install, logs are not displayed
# !pip install -q streamlit
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 92.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 86.9 MB/s eta 0:00:00

# %% [markdown]
# # Get API key in the file (Never share it publicly)

# %%
with open("key.txt", "r") as f:
    api = f.read()

# %% [markdown]
# # Import libraries

# %%
import google.generativeai as genai
import streamlit as st

# %% [markdown]
# # Configure model

# %%
genai.configure(api_key = api)

# %% [markdown]
# # Load Model

# %%
model = genai.GenerativeModel("gemini-3.5-flash") #load whichever model is available

# %%
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-3.5-flash',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %% [markdown]
# # Generate response

# %%
response = model.generate_content("What is the capital of Panama? Give short response.")
print(response.text)
# Out:
# The capital of Panama is **Panama City**.

# %%
response
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "The capital of Panama is **Panama City**."
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "index": 0
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 12,
#         "candidates_token_count": 10,
#         "total_token_count": 113
#       },
#       "model_version": "gemini-3.5-flash"
#     }),
# )

# %%
import google.generativeai as genai
print(genai.__version__)
# Out:
# 0.8.6

# %% [markdown]
# # cleaning up the text

# %%
clean_text = str(response.text).replace('*', '')
print(clean_text)
# Out:
# The capital of Panama is Panama City.

# %% [markdown]
# # Installing ngrok and setting it up

# %%
# !pip install -q pyngrok

# %%
# !pyngrok --version
# Out:
# ngrok version 3.39.10
# pyngrok version 8.1.2

# %%
with open("ngrok_authenticator_code.txt", "r") as f:
    ngrok_auth_key = f.read()

# %%
from pyngrok import ngrok # importing the library
# !ngrok config add-authtoken {ngrok_auth_key} # setting the ngrok tunnel to host the website
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %% [markdown]
# # Creating app.py file that has out chatbot code

# %%
user_input = input("say something ")
# Out:
# say something hi

# %%
user_input
# Out:
# 'hi'

# %%
with open("app.py", "w") as f:
    f.write(f"""# app.py

import streamlit as st
import google.generativeai as genai

# Configure Gemini API
genai.configure(api_key = '{api}')

# Load model
model = genai.GenerativeModel("gemini-3.5-flash")

# Streamlit page
st.set_page_config(page_title="Gemini Chatbot")

st.title("🤖 Yash study assistant")

# Input box
user_input = st.text_input("Ask something")

# Generate response
if user_input:
    response = model.generate_content(user_input)
    clean_text = response.text.replace('*', '')
    st.write(clean_text)""")

# %%
import streamlit as st
st.set_page_config(page_title="Gemini Chatbot")
# Out:
# 2026-07-28 06:04:29.088 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
public_url = ngrok.connect(8501)

# %% [markdown]
# # Hosting app on streamlit using ngrok

# %%
print(public_url)
# !streamlit run app.py &  #to run streamlit app
# Out:
# NgrokTunnel: "https://reunion-acclaim-exclaim.ngrok-free.dev" -> "http://localhost:8501"
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# 2026-07-28 06:04:43.264 Uvicorn server started on :::8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://8.234.162.37:8501
#
# /content/app.py:4: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %% [markdown]
# # Adding Memory

# %%
chat_history = []

# %%
chat_history.append(
    "User: My name is yash"
)

# %%
chat_history.append(
    "Assistant: Nice to meet you"
)

# %%
chat_history

# %%
context = "\n".join(chat_history)
print(context)

# %%
type(context)

# %%
prompt = context + "\nUser: What is my name?"

print(prompt)

# %%
response = model.generate_content(prompt)
print(response.text)

# %%
SYSTEM_PROMPT = """
You are a friendly AI study assistant.

Rules:
- explain simply
- use examples
- encourage learning
- do not go out of topic
"""

# %%
full_prompt = f"""
{SYSTEM_PROMPT}

{context}

Assistant:
"""
print(full_prompt)
# Out:
# You are a friendly AI study assistant.
#
# Rules:
# - explain simply
# - use examples
# - encourage learning
# - do not go out of topic
#
#
# User: My name is Akangsha
# Assistant: Nice to meet you
#
# Assistant:

# %%
with open("app1.py", "w") as f:
    f.write(f'''
import streamlit as st
import google.generativeai as genai

gemini_api_key = st.secrets["GEMINI_API_KEY"]

genai.configure(api_key=gemini_api_key)

model = genai.GenerativeModel("gemini-3.5-flash")

SYSTEM_PROMPT = """
You are a helpful AI assistant.
Remember details shared in the conversation and answer accordingly.
"""

st.set_page_config(page_title="Memory Chatbot")

st.title("🧠 Akangsha's Memory Assistant")

if "chat_history" not in st.session_state:
    st.session_state.chat_history = []

for message in st.session_state.chat_history:
    with st.chat_message(message["role"]):
        st.write(message["content"])

user_input = st.chat_input("Ask something...")

if user_input:

    st.session_state.chat_history.append(
        {{
            "role": "user",
            "content": user_input
        }}
    )

    conversation_text = ""

    for message in st.session_state.chat_history:

        if message["role"] == "user":
            conversation_text += f"User: {{message['content']}}\\n"

        else:
            conversation_text += f"Assistant: {{message['content']}}\\n"

    full_prompt = f"""
{{SYSTEM_PROMPT}}

{{conversation_text}}

Assistant:
"""

    try:
        response = model.generate_content(full_prompt)
        assistant_reply = response.text

    except Exception as e:
        assistant_reply = f"Error: {{str(e)}}"

    st.session_state.chat_history.append(
        {{
            "role": "assistant",
            "content": assistant_reply
        }}
    )

    st.rerun()

if st.button("🗑️ Clear Chat"):
    st.session_state.chat_history = []
    st.rerun()
''')

# %%
for m in genai.list_models():
    print(m.name)

# %%
from pyngrok import ngrok # importing the library
# !ngrok config add-authtoken {ngrok_auth_key} # setting the ngrok tunnel to host the website
public_url = ngrok.connect(8501)

print(public_url)
# !streamlit run app1.py &  #to run streamlit app
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# NgrokTunnel: "https://992b-34-169-160-200.ngrok-free.app" -> "http://localhost:8501"
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# 2026-06-04 07:04:24.783 Uvicorn server started on 0.0.0.0:8501
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.169.160.200:8501
#
# /content/app1.py:3: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai
# WARNING:pyngrok.process.ngrok:t=2026-06-04T07:07:38+0000 lvl=warn msg="Stopping forwarder" name=http-8501-08d1a719-f412-437c-b115-7c82115b3231 acceptErr="failed to accept connection: Listener closed"
# WARNING:pyngrok.process.ngrok:t=2026-06-04T07:07:38+0000 lvl=warn msg="Error restarting forwarder" name=http-8501-08d1a719-f412-437c-b115-7c82115b3231 err="failed to start tunnel: remote gone away"
#   Stopping...

# %% [markdown]
# ## Knowledge Injection

# %%
with open("notes.txt","r") as f:
    notes = f.read()

print(notes[:500])
# Out:
# In the interplanet tournament, The Mars team dominated the Galactic Sphere League this season, a fast-paced game played with floating energy orbs on anti-gravity arenas. Known for their lightning passes and clever formations, Mars won 18 of 20 matches and captured the Crimson Cup. Captain Akangsha Goswami led the squad with exceptional strategy, while striker Madhuri Dixit scored a league-record 42 orb-goals. Fans packed the Sky Dome every week to watch their thrilling comebacks and spectacular

# %%
response = model.generate_content("What is the interplanet tournament?")

print(response.text)
# Out:
# Because the term **"Interplanet Tournament"** (or **"Interplanetary Tournament"**) is used in several different fictional universes—primarily in anime, video games, and sci-fi—the exact definition depends on the context you are referring to.
#
# Here are the most famous "interplanetary tournaments" in pop culture:
#
# ---
#
# ### 1. *Inazuma Eleven GO: Galaxy* (Grand Celesta Galaxy)
# In this popular anime and video game series, the **Grand Celesta Galaxy** is an interplanetary soccer (football) tournament.
# * **The Plot:** Earth is forced to enter a soccer tournament against teams from other planets. If Earth's team (Earth Eleven) loses, the planet will be destroyed by an incoming black hole, or invaded by the alien empires organizing the tournament.
# * **Significance:** It is the ultimate test of humanity's "soul" power against diverse alien species with unique abilities.
#
# ### 2. *Dragon Ball Z: Bojack Unbound* (The Intergalactic Tournament)
# While technically called the "Intergalactic World Tournament," this is one of the most famous planetary-level martial arts tournaments in anime.
# * **The Plot:** Funded by a multi-millionaire, this tournament features fighters from Earth and across the galaxy. The arena features different zones representing different climates of various planets.
# * **The Twist:** The tournament is hijacked by the space pirate Bojack and his crew, turning a friendly competition into a fight for survival for Gohan, Trunks, and the other Z-Fighters.
#
# ### 3. *Unreal Tournament* (Video Game Series)
# In the classic sci-fi first-person shooter franchise *Unreal Tournament*, the tournament is a brutal, futuristic gladiatorial event.
# * **The Plot:** Run by the Liandri Mining Corporation, the tournament takes place on various planets, moons, and space stations across the galaxy. It was created to channel the violent impulses of deep-space miners and soldiers into a highly profitable, televised sport.
#
# ### 4. *Mortal Kombat* (Inter-Realm Tournament)
# While usually referred to as "inter-dimensional" or "inter-realm," the Mortal Kombat tournament functions essentially as an interplanetary martial arts tournament.
# * **The Plot:** Warriors from Earthrealm (Earth) must fight against the warriors of Outworld and other realms/planets. If Outworld wins ten consecutive tournaments, they earn the right to invade and conquer Earth.
#
# ---
#
# ### Other Niche Possibilities:
# * **Board Games / Tabletop:** There are various sci-fi board games and RPG campaigns (like *Warhammer 40k* or custom *Dungeons & Dragons* spelljammer campaigns) that feature interplanetary tournaments of mech-fighting, racing, or gladiatorial combat.
# * **Esports:** Occasionally, major regional esports tournaments (like in *StarCraft* or *Halo*) use "Interplanetary" or "Intergalactic" as a thematic branding name.
#
# **Which specific franchise or context were you looking for?** If you can provide a bit more detail, I can give you a much more specific answer!

# %%
question = "What is interplanet tournament? who won and how?"

prompt = f"""
Use the knowledge below.

KNOWLEDGE:
{notes}

QUESTION:
{question}
"""

# %%
prompt
# Out:
# '\nUse the knowledge below.\n\nKNOWLEDGE:\nIn the interplanet tournament, The Mars team dominated the Galactic Sphere League this season, a fast-paced game played with floating energy orbs on anti-gravity arenas. Known for their lightning passes and clever formations, Mars won 18 of 20 matches and captured the Crimson Cup. Captain Akangsha Goswami led the squad with exceptional strategy, while striker Madhuri Dixit scored a league-record 42 orb-goals. Fans packed the Sky Dome every week to watch their thrilling comebacks and spectacular aerial plays. Despite fierce competition from rival teams Venus and Titan, Mars remained undefeated at home and finished the season as champions.\n\nQUESTION:\nWhat is interplanet tournament? who won and how?\n'

# %%
response = model.generate_content(prompt)

print(response.text)
# Out:
# Based on the provided text:
#
# * **What is the interplanet tournament?**
# It is the Galactic Sphere League, which is described as a fast-paced game played with floating energy orbs on anti-gravity arenas.
#
# * **Who won?**
# The Mars team won the tournament, capturing the Crimson Cup and finishing the season as champions.
#
# * **How did they win?**
# They won by:
# * Winning 18 of 20 matches and remaining undefeated at home.
# * Employing lightning passes, clever formations, thrilling comebacks, and spectacular aerial plays.
# * Being led by Captain Akangsha Goswami's exceptional strategy.
# * Having striker Madhuri Dixit score a league-record 42 orb-goals.
